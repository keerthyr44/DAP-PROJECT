# %%
# spam_detector_project.py

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns



# Load Dataset
df = pd.read_excel("sample_20x10_dataset.xlsx")

#head
df.head()
# Out:
#   label                                               text  label_num  \
# 0   ham  Subject: hpl nom for march 30 , 2001\n( see at...          0
# 1  spam  Subject: online pharxmacy 80 % off all meds\nd...          1
# 2   ham  Subject: re : nom / actual volume for april 17...          0
# 3   ham  Subject: re : meter 8740 dec 99\nrobert and i ...          0
# 4   ham  Subject: re : coastal oil & gas corporation\nm...          0
#
#    text_length  word_count  char_density  num_uppercase  num_exclamations  \
# 0           94          23      4.086957              1                 0
# 1        21749        2731      7.963750              1                 2
# 2          400         102      3.921569              1                 0
# 3         3456         863      4.004635              1                 0
# 4        13178        3291      4.004254              1                 3
#
#    num_numbers
# 0           12
# 1            4
# 2           37
# 3          126
# 4          689

# %%
#info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   label             20 non-null     object
#  1   text              20 non-null     object
#  2   label_num         20 non-null     int64
#  3   text_length       20 non-null     int64
#  4   word_count        20 non-null     int64
#  5   char_density      20 non-null     float64
#  6   num_uppercase     20 non-null     int64
#  7   num_exclamations  20 non-null     int64
#  8   num_numbers       20 non-null     int64
# dtypes: float64(1), int64(6), object(2)
# memory usage: 1.5+ KB

# %%
# Label Distribution
sns.countplot(x='label', data=df)
plt.title("Distribution of Spam vs Ham")
plt.show()

# %%
sns.histplot(data=df, x='text_length', hue='label', multiple='stack')
plt.title("Text Length Distribution by Label")
plt.show()

# %%
print("/n Descrpitive Statistics:")
print(df.describe)
# Out:
# /n Descrpitive Statistics:
# <bound method NDFrame.describe of    label                                               text  label_num  \
# 0    ham  Subject: hpl nom for march 30 , 2001\n( see at...          0
# 1   spam  Subject: online pharxmacy 80 % off all meds\nd...          1
# 2    ham  Subject: re : nom / actual volume for april 17...          0
# 3    ham  Subject: re : meter 8740 dec 99\nrobert and i ...          0
# 4    ham  Subject: re : coastal oil & gas corporation\nm...          0
# 5    ham  Subject: enron / hpl actuals for july 27 , 200...          0
# 6    ham  Subject: re : meter 98 - 9699 & 98 - 2662 ( re...          0
# 7    ham  Subject: hpl nom for may 3 , 2001\n( see attac...          0
# 8    ham  Subject: enron / hpl noms for february 23 - 25...          0
# 9    ham  Subject: tenaska iv transport 10 / 00\ni took ...          0
# 10   ham  Subject: moving the list . . .\nbammelyoungfam...          0
# ...

# %%
import seaborn as sns
sns.pairplot(df, hue='label', vars=['text_length', 'word_count', 'char_density', 'num_exclamations', 'num_numbers'])
plt.show()

# %%
{column:len(df[column].unique()) for column in df.columns}
# Out:
# {'label': 2,
#  'text': 20,
#  'label_num': 2,
#  'text_length': 20,
#  'word_count': 19,
#  'char_density': 20,
#  'num_uppercase': 1,
#  'num_exclamations': 6,
#  'num_numbers': 18}

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load dataset
file_path = 'sample_20x10_dataset.xlsx'
df = pd.read_excel(file_path)

# Count labels
label_counts = df['label'].value_counts()

# Pie chart
plt.figure(figsize=(6, 6))
plt.pie(label_counts, labels=label_counts.index, autopct='%1.1f%%', startangle=140, colors=['#66b3ff','#ff9999'])

# Add title
plt.title('Label Distribution: Spam vs Ham', fontsize=14)

# Show plot
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_excel("sample_20x10_dataset.xlsx")

sns.boxplot(x="label", y="text_length", data=df)
plt.title("Text Length by Label")
plt.show()

# %%
df.tail()
# Out:
#    label                                               text  label_num  \
# 15   ham  Subject: revisions - march wellhead estimate\n...          0
# 16   ham  Subject: revision # 1 - hpl nom for august 11 ...          0
# 17   ham  Subject: cp & l\nthanks for your help .\nrebec...          0
# 18  spam  Subject: upgrade your os to xp pro for $ 50\nw...          1
# 19   ham  Subject: re : valero - - meter 8018\nok , it l...          0
#
#     text_length  word_count  char_density  num_uppercase  num_exclamations  \
# 15         1501         392      3.829082              1                 0
# 16          108          27      4.000000              1                 0
# 17          395         127      3.110236              1                 0
# 18         1640         305      5.377049              1                 1
# 19         1235         319      3.871473              1                 0
#
#     num_numbers
# 15          194
# 16           13
# 17           30
# 18          146
# ...

# %%
import pandas as pd

# Load the Excel file
df = pd.read_excel("sample_20x10_dataset.xlsx")  # update the path if needed

# Check for missing values
print("\nMissing values per column:")
print(df.isnull().sum())

# Drop rows with missing values (if any)
df_cleaned = df.dropna()

# Drop duplicate rows (if any)
df_cleaned = df_cleaned.drop_duplicates()
# Out:
# Missing values per column:
# label               0
# text                0
# label_num           0
# text_length         0
# word_count          0
# char_density        0
# num_uppercase       0
# num_exclamations    0
# num_numbers         0
# dtype: int64
